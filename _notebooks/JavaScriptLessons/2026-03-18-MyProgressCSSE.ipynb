# %% [markdown]
# ---
# layout: post
# categories: CSSE Achevements
# codemirror: true
# microblog: true
# title: Achivements
# description: My achiments through my CSSE Journey.
# permalink: /blogs/achivements
# author: Rohit Datla
# ---

# %% [markdown]
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Exo+2:wght@300;400;600&display=swap');
# *{box-sizing:border-box}
# :root{--c:#00f5ff;--m:#ff00c8;--g:#00ff88;--bg:#020810;--p:#0a1628;--b:#0d2847;--tx:#c8e0f4;--dm:#4a6b8a}
# .pr{font-family:'Exo 2',sans-serif;background:var(--bg);color:var(--tx);padding:0 0 40px}
# .gbg{position:fixed;inset:0;background-image:linear-gradient(rgba(0,245,255,.03) 1px,transparent 1px),linear-gradient(90deg,rgba(0,245,255,.03) 1px,transparent 1px);background-size:44px 44px;pointer-events:none;z-index:0}
# .gbg::after{content:'';position:absolute;inset:0;background:radial-gradient(ellipse 80% 50% at 50% 0%,rgba(0,245,255,.09),transparent)}
# .scan{position:fixed;inset:0;background:repeating-linear-gradient(to bottom,transparent 0,transparent 3px,rgba(0,0,0,.07) 3px,rgba(0,0,0,.07) 4px);pointer-events:none;z-index:1}
# .wrap{position:relative;z-index:2;max-width:900px;margin:0 auto;padding:0 28px}
# .hero{text-align:center;padding:52px 0 44px}
# .h-tag{font-family:'Share Tech Mono',monospace;font-size:11px;color:var(--c);letter-spacing:5px;text-transform:uppercase;opacity:0;animation:fadeUp .5s ease forwards .2s}
# .h-title{font-family:'Orbitron',sans-serif;font-size:clamp(28px,5vw,58px);font-weight:900;letter-spacing:3px;background:linear-gradient(135deg,#fff 0%,#00f5ff 45%,#ff00c8 100%);-webkit-background-clip:text;-webkit-text-fill-color:transparent;background-clip:text;opacity:0;animation:fadeUp .6s ease forwards .35s,flicker 7s infinite 3.5s}
# .h-sub{font-family:'Share Tech Mono',monospace;font-size:13px;color:var(--dm);letter-spacing:3px;opacity:0;animation:fadeUp .6s ease forwards .55s}
# .h-line{width:0;height:1px;background:linear-gradient(90deg,transparent,#00f5ff,#ff00c8,transparent);margin:24px auto 0;animation:expandLine .9s ease forwards 1s}
# .cursor{display:inline-block;width:2px;height:.9em;background:var(--c);margin-left:2px;vertical-align:middle;animation:blink 1s step-end infinite}
# .sec{margin:52px 0 28px;opacity:0;animation:fadeUp .6s ease forwards}
# .sec:nth-child(1){animation-delay:.7s}.sec:nth-child(2){animation-delay:.9s}.sec:nth-child(3){animation-delay:1.1s}.sec:nth-child(4){animation-delay:1.3s}
# .sec-hdr{display:flex;align-items:center;gap:14px;margin-bottom:24px}
# .sec-ico{font-size:17px;width:40px;height:40px;display:flex;align-items:center;justify-content:center;border:1px solid var(--c);color:var(--c);flex-shrink:0;animation:pulseGlow 3s ease-in-out infinite}
# .sec-ttl{font-family:'Orbitron',sans-serif;font-size:15px;font-weight:700;letter-spacing:3px;text-transform:uppercase;color:#fff}
# .sec-ttl span{color:var(--c)}
# .sec-line{flex:1;height:1px;background:linear-gradient(90deg,var(--b),transparent)}
# .sg{display:grid;grid-template-columns:repeat(auto-fit,minmax(180px,1fr));gap:12px}
# .sk{background:var(--p);border:1px solid var(--b);padding:16px 18px;position:relative;overflow:hidden;transition:border-color .3s,transform .3s}
# .sk::before{content:'';position:absolute;top:0;left:0;width:3px;height:100%;background:var(--c);opacity:0;transition:opacity .3s}
# .sk:hover{border-color:var(--c);transform:translateY(-2px)}.sk:hover::before{opacity:1}
# .sk-name{font-family:'Share Tech Mono',monospace;font-size:12px;color:var(--tx);margin-bottom:9px;letter-spacing:1px}
# .sk-trk{height:3px;background:var(--b);overflow:hidden}
# .sk-fill{height:100%;background:linear-gradient(90deg,#00f5ff,#ff00c8);width:0;animation:fillBar 1.1s ease forwards;animation-delay:var(--d,1s)}
# .sk-lv{font-family:'Share Tech Mono',monospace;font-size:10px;color:var(--c);text-align:right;margin-top:5px}
# .pc{background:var(--p);border:1px solid var(--b);padding:24px 26px;margin-bottom:14px;transition:border-color .3s,box-shadow .3s}
# .pc:hover{border-color:rgba(0,245,255,.4);box-shadow:0 0 28px rgba(0,245,255,.07)}
# .pc-num{font-family:'Orbitron',sans-serif;font-size:10px;color:var(--m);letter-spacing:3px;margin-bottom:6px}
# .pc-ttl{font-family:'Orbitron',sans-serif;font-size:18px;font-weight:700;color:#fff;margin-bottom:12px}
# .pc-tags{display:flex;flex-wrap:wrap;gap:7px;margin-bottom:16px}
# .tag{font-family:'Share Tech Mono',monospace;font-size:10px;padding:3px 9px;border:1px solid var(--c);color:var(--c);background:rgba(0,245,255,.05)}
# .pc-flds{display:grid;grid-template-columns:1fr 1fr;gap:12px}
# .fl{font-family:'Share Tech Mono',monospace;font-size:10px;color:var(--m);letter-spacing:2px;text-transform:uppercase;margin-bottom:5px}
# .fv{font-size:12px;color:var(--dm);font-style:italic;line-height:1.5}
# .gg{display:grid;grid-template-columns:repeat(auto-fit,minmax(220px,1fr));gap:14px}
# .gc{background:var(--p);border:1px solid var(--b);padding:22px;position:relative;transition:transform .3s,border-color .3s}
# .gc:hover{transform:translateY(-3px);border-color:var(--g)}
# .g-ico{font-size:22px;margin-bottom:10px}
# .g-type{font-family:'Share Tech Mono',monospace;font-size:10px;color:var(--g);letter-spacing:3px;text-transform:uppercase;margin-bottom:7px}
# .g-txt{font-size:12px;color:var(--dm);line-height:1.6;font-style:italic}
# .g-corner{position:absolute;bottom:0;right:0;width:36px;height:36px;border-top:1px solid var(--g);border-left:1px solid var(--g);opacity:.3}
# .term{background:#010a04;border:1px solid #0f3320;padding:22px 26px;font-family:'Share Tech Mono',monospace}
# .t-bar{display:flex;align-items:center;gap:7px;margin-bottom:16px;padding-bottom:13px;border-bottom:1px solid #0f3320}
# .td{width:9px;height:9px;border-radius:50%}
# .t-ttl{font-size:11px;color:#2a6641;margin-left:6px;letter-spacing:2px}
# .tl{font-size:12px;line-height:2;color:#3a9955}
# .tl .p{color:#00ff88;margin-right:9px}.tl .c{color:#7ad6a0}.tl .o{color:#3a7750;margin-left:20px;display:block}
# .ftr{text-align:center;padding:44px 0 28px;border-top:1px solid var(--b);margin-top:56px;font-family:'Share Tech Mono',monospace;font-size:11px;color:var(--dm);letter-spacing:2px}
# .fg{color:var(--c);text-shadow:0 0 8px var(--c)}
# @keyframes fadeUp{from{opacity:0;transform:translateY(18px)}to{opacity:1;transform:translateY(0)}}
# @keyframes expandLine{to{width:340px}}
# @keyframes fillBar{to{width:var(--fill)}}
# @keyframes blink{0%,100%{opacity:1}50%{opacity:0}}
# @keyframes pulseGlow{0%,100%{box-shadow:0 0 8px rgba(0,245,255,.3)}50%{box-shadow:0 0 20px rgba(0,245,255,.7)}}
# @keyframes flicker{0%,100%{opacity:1}48%{opacity:1}50%{opacity:.86}52%{opacity:1}}
# </style>
#
# <div class='pr'><div class='gbg'></div><div class='scan'></div>
# <div class='wrap'>
# <div class='hero'>
#   <div class='h-tag'>// computer science &nbsp;&bull;&nbsp; student portfolio &nbsp;&bull;&nbsp; 2026</div>
#   <h1 class='h-title'>MY CS PORTFOLIO</h1>
#   <div class='h-sub'>SKILLS &nbsp;/&nbsp; PROJECTS &nbsp;/&nbsp; GOALS<span class='cursor'></span></div>
#   <div class='h-line'></div>
# </div>
#
# <div class='sec'>
#   <div class='sec-hdr'><div class='sec-ico'>⚡</div><div class='sec-ttl'><span>01.</span> Skills acquired</div><div class='sec-line'></div></div>
#   <div class='sg'>
#     <div class='sk'><div class='sk-name'>PYTHON</div><div class='sk-trk'><div class='sk-fill' style='--fill:95%;--d:1.1s'></div></div><div class='sk-lv'>★★★★☆ 4 </div></div>
#     <div class='sk'><div class='sk-name'>HTML & CSS</div><div class='sk-trk'><div class='sk-fill' style='--fill:69%;--d:1.3s'></div></div><div class='sk-lv'>★★★☆☆ 3 </div></div>
#     <div class='sk'><div class='sk-name'>JAVASCRIPT</div><div class='sk-trk'><div class='sk-fill' style='--fill:%;--d:1.5s'></div></div><div class='sk-lv'>★★★☆☆ 3 </div></div>
#     <div class='sk'><div class='sk-name'>ALGORITHMS</div><div class='sk-trk'><div class='sk-fill' style='--fill:65%;--d:1.7s'></div></div><div class='sk-lv'>★★★★☆ 4 </div></div>
#     <div class='sk'><div class='sk-name'>DEBUGGING</div><div class='sk-trk'><div class='sk-fill' style='--fill:80%;--d:1.9s'></div></div><div class='sk-lv'>★★★★☆ 4 </div></div>
#     <div class='sk'><div class='sk-name'>OOP CONCEPTS</div><div class='sk-trk'><div class='sk-fill' style='--fill:60%;--d:2.1s'></div></div><div class='sk-lv'>★★★☆☆ 3 </div></div>
#   </div>
# </div>
#
# <div class='sec'>
#   <div class='sec-hdr'><div class='sec-ico'>🚀</div><div class='sec-ttl'><span>02.</span> My projects</div><div class='sec-line'></div></div>
#   <div class='pc'><div class='pc-num'>PROJECT // 001</div><div class='pc-ttl'>[ Mansion Game level 5 ]</div>
#   <div class='pc-tags'><span class='tag'>Javascript</span><span class='tag'>VS CODE</span><span class='tag'>HTML</span></div>
#   <div class='pc-flds'><div><div class='fl'>▸ What I built</div><div class='fv'>I built a system where multiple zombies appeared and attacked the player.</div></div><div><div class='fl'>▸ Challenges</div><div class='fv'>The game was lagging because multiple enimies were checking position at once which lagged the game.</div></div><div><div class='fl'>▸ Proud of</div><div class='fv'> I was succeslfuly able to optimize the game so that it would not lagged and was able to be played smoothly.</div></div><div><div class='fl'>▸ Takeaway</div><div class='fv'>I learned a lot from this project like basics of Javscript porgraming and other languages, working with a team, and planning with a group og people.</div></div></div></div>
# <!-- This is Tag Game-->
#   <div class='pc'><div class='pc-num'>PROJECT // 002</div><div class='pc-ttl'>[ Tag Game ]</div>
#   <div class='pc-tags'><span class='tag'>HTML</span><span class='tag'>CSS</span><span class='tag'>EDIT TAGS</span></div>
#   <div class='pc-flds'><div><div class='fl'>▸ What I built</div><div class='fv'> I built a fully functional tag game where you can tag an ai which is able to deploy sratagies and understand how you play.</div></div><div><div class='fl'>▸ Challenges</div><div class='fv'>Some challanges were trying to fix the AI to make it work well, and know when to follow the player and when to run away from player.</div></div><div><div class='fl'>▸ Proud of</div><div class='fv'>creating smart NPC </div></div><div><div class='fl'>▸ Takeaway</div><div class='fv'>I leanred many things through thsi projecet.</div></div></div></div>
#
#   <div class='pc'><div class='pc-num'>PROJECT // 003</div><div class='pc-ttl'>[ Data abstraciton lesson ]</div>
#   <div class='pc-tags'><span class='tag'>JAVASCRIPT</span><span class='tag'>Jypiter Notebooks</span></div>
#   <div class='pc-flds'><div><div class='fl'>▸ What I built</div><div class='fv'>Made javascript lessons where we thouaght about data abstraction</div></div><div><div class='fl'>▸ Challenges</div><div class='fv'>making better UI.</div></div><div><div class='fl'>▸ Proud of</div><div class='fv'>Helped make a complex way in a website to learn basics </div></div><div><div class='fl'>▸ Takeaway</div><div class='fv'>learned how to use jypiter notebooks to create different things</div></div></div></div>
# </div>
#
# <div class='sec'>
#   <div class='sec-hdr'><div class='sec-ico'>🎯</div><div class='sec-ttl'><span>03.</span> Goals & reflections</div><div class='sec-line'></div></div>
#   <div class='gg'>
#     <div class='gc'><div class='g-ico'>⚡</div><div class='g-type'>Short-term goal</div><div class='g-txt'>Edit this with your own short-term goal!</div><div class='g-corner'></div></div>
#     <div class='gc'><div class='g-ico'>🛰️</div><div class='g-type'>Long-term goal</div><div class='g-txt'>Edit this with your own long-term goal!</div><div class='g-corner'></div></div>
#     <div class='gc'><div class='g-ico'>🌌</div><div class='g-type'>Stretch goal</div><div class='g-txt'>Edit this with your most ambitious goal!</div><div class='g-corner'></div></div>
#   </div>
# </div>
#
# <div class='sec'>
#   <div class='sec-hdr'><div class='sec-ico'>💬</div><div class='sec-ttl'><span>04.</span> Reflection log</div><div class='sec-line'></div></div>
#   <div class='term'>
#     <div class='t-bar'><div class='td' style='background:#ff5f57'></div><div class='td' style='background:#febc2e'></div><div class='td' style='background:#28c840'></div><span class='t-ttl'>student@portfolio:~$ reflection.log</span></div>
#     <div class='tl'><span class='p'>$</span><span class='c'>Mansion_Game.txt</span></div>
#     <div class='tl'><span class='o'>→ [ Edit: I have learned how to use the basic version of code builder to create a game ]</span></div>
#     <div class='tl'><span class='p'>$</span><span class='c'>cat challenges.txt</span></div>
#     <div class='tl'><span class='o'>→ [ Edit: Some of the challenges that I had to face through out my journey of Comp Sci was trying to adapt to other peoples code and be social and apart of a team, which also helped me in other subjects as i was more able to plan and orginise instead of doing things by my slef ]</span></div>
#     <div class='tl'><span class='p'>$</span><span class='c'>cat favorite_part.txt</span></div>
#     <div class='tl'><span class='o'>→ [ Edit: Even though struggles are going to happen I personaly enjoy computer science and I love the subject, which helps me through any challenge I face. ]</span></div>
#     <div class='tl'><span class='p'>$</span><span class='c'>_<span class='cursor'></span></span></div>
#   </div>
# </div>
#
# <div class='ftr'><span class='fg'></></span> &nbsp; portfolio last updated: march 2026 &nbsp; <span class='fg'></></span></div>
# </div></div>
